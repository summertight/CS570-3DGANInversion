# %%
image_path = '/home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop'
#name = 'seed0000'
path_out = f'/home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/yufeng_crop.mp4'
fps = 30
import cv2, os
frame_array = []
paths = [os.path.join(image_path, i.split('.')[0].zfill(4)+'.png') for i in os.listdir(image_path)]
paths = sorted(paths)
for path in paths:
    if path[-3:]=='png':
        #print('1')
        print(path)
        try:
            real_path = '/home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/'+str(int(path.split('/')[-1].split('.')[0]))+'.png'
            img = cv2.imread(real_path)
            height, width, layers = img.shape
            size = (width,height)
            frame_array.append(img)
        except:
            pass
out = cv2.VideoWriter(path_out,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
for i in range(len(frame_array)):
    # writing to a image array
    out.write(frame_array[i])
out.release()
# Out:
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0001.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0002.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0003.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0004.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0005.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0006.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0007.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0008.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0009.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0010.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0011.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0012.png
# /home/nas4_user/jaeseonglee/ICCV2023/yufeng_preprocessed/crop/0013.png
# ...
